# %%
import pandas as pd

# %%
df = pd.read_csv('./train.csv')

# %%
df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726
# std       1.112799    30.202904     20.645407   181.066207   456.098091
# ...

# %%
df.columns
# Out:
# Index([u'Id', u'MSSubClass', u'MSZoning', u'LotFrontage', u'LotArea',
#        u'Street', u'Alley', u'LotShape', u'LandContour', u'Utilities',
#        u'LotConfig', u'LandSlope', u'Neighborhood', u'Condition1',
#        u'Condition2', u'BldgType', u'HouseStyle', u'OverallQual',
#        u'OverallCond', u'YearBuilt', u'YearRemodAdd', u'RoofStyle',
#        u'RoofMatl', u'Exterior1st', u'Exterior2nd', u'MasVnrType',
#        u'MasVnrArea', u'ExterQual', u'ExterCond', u'Foundation', u'BsmtQual',
#        u'BsmtCond', u'BsmtExposure', u'BsmtFinType1', u'BsmtFinSF1',
#        u'BsmtFinType2', u'BsmtFinSF2', u'BsmtUnfSF', u'TotalBsmtSF',
#        u'Heating', u'HeatingQC', u'CentralAir', u'Electrical', u'1stFlrSF',
#        u'2ndFlrSF', u'LowQualFinSF', u'GrLivArea', u'BsmtFullBath',
#        u'BsmtHalfBath', u'FullBath', u'HalfBath', u'BedroomAbvGr',
#        u'KitchenAbvGr', u'KitchenQual', u'TotRmsAbvGrd', u'Functional',
# ...

# %%
Y = df['SalePrice']

# %%
Y.describe()
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %%
import matplotlib.pyplot as plt
plt.clf()
Y.hist(bins=10).figure

# %%
import numpy as np
Y = np.log(Y)

# %%
Y.hist(bins=10).figure

# %%
df['SalePrice'] = np.log(df['SalePrice'])

# %% [markdown]
# Explore factors

# %%
df_subclass = pd.get_dummies(df['MSSubClass'], prefix='MSSubClass')

# %%
df.corr()
# Out:
#                      Id  MSSubClass  LotFrontage   LotArea  OverallQual  \
# Id             1.000000    0.011156    -0.010601 -0.033226    -0.028365
# MSSubClass     0.011156    1.000000    -0.386347 -0.139781     0.032628
# LotFrontage   -0.010601   -0.386347     1.000000  0.426095     0.251646
# LotArea       -0.033226   -0.139781     0.426095  1.000000     0.105806
# OverallQual   -0.028365    0.032628     0.251646  0.105806     1.000000
# OverallCond    0.012609   -0.059316    -0.059213 -0.005636    -0.091932
# YearBuilt     -0.012713    0.027850     0.123349  0.014228     0.572323
# YearRemodAdd  -0.021998    0.040581     0.088866  0.013788     0.550684
# MasVnrArea    -0.050298    0.022936     0.193458  0.104160     0.411876
# BsmtFinSF1    -0.005024   -0.069836     0.233633  0.214103     0.239666
# BsmtFinSF2    -0.005968   -0.065649     0.049900  0.111170    -0.059119
# BsmtUnfSF     -0.007940   -0.140759     0.132644 -0.002618     0.308159
# ...

# %%
plt.clf()
df.groupby(['MSSubClass'])['SalePrice'].mean().plot.bar()
plt.show()

# %% [markdown]
# From the figure, we can see that the column 'MSSubClass' is not very relevant to SalePrice, so we can omit it in the begining

# %%
df = df.drop(['MSSubClass'], axis=1)

# %%
plt.clf()
df.groupby(['MSZoning'])['SalePrice'].mean().plot.bar()
plt.show()

# %% [markdown]
# More correlated than MSSubClass, but I think still can be omitted in the beginning

# %%
df = df.drop(['MSZoning'], axis=1)

# %%
plt.clf()
df.plot.scatter('LotFrontage', 'SalePrice')
plt.show()

# %%
plt.clf()
df.plot.scatter('OverallQual', 'SalePrice')
plt.show()

# %%
factors = ['OverallQual']

# %%
plt.clf()
df.plot.scatter('YearBuilt', 'SalePrice')
plt.show()

# %%
factors.append('YearBuilt')

# %%
plt.clf()
df.plot.scatter('MasVnrArea', 'SalePrice')
plt.show()

# %%
plt.clf()
df.groupby(['MasVnrType'])['SalePrice'].mean().plot.bar()
plt.show()

# %%
plt.clf()
df.groupby(['MasVnrType'])['SalePrice'].std().plot.bar()
plt.show()

# %%
factors.append('MasVnrArea')

# %%
df.corr()[10:]
# Out:
#                      Id  LotFrontage   LotArea  OverallQual  OverallCond  \
# BsmtUnfSF     -0.007940     0.132644 -0.002618     0.308159    -0.136841
# TotalBsmtSF   -0.015415     0.392075  0.260833     0.537808    -0.171098
# 1stFlrSF       0.010496     0.457181  0.299475     0.476224    -0.144203
# 2ndFlrSF       0.005590     0.080177  0.050986     0.295493     0.028942
# LowQualFinSF  -0.044230     0.038469  0.004779    -0.030429     0.025494
# GrLivArea      0.008273     0.402797  0.263116     0.593007    -0.079686
# BsmtFullBath   0.002289     0.100949  0.158155     0.111098    -0.054942
# BsmtHalfBath  -0.020155    -0.007234  0.048046    -0.040150     0.117821
# FullBath       0.005587     0.198769  0.126031     0.550600    -0.194149
# HalfBath       0.006784     0.053532  0.014259     0.273458    -0.060769
# BedroomAbvGr   0.037719     0.263170  0.119690     0.101676     0.012980
# KitchenAbvGr   0.002951    -0.006069 -0.017784    -0.183882    -0.087001
# ...

# %%
plt.clf()
df.plot.scatter('GrLivArea', 'SalePrice')
plt.show()

# %%
factors.append('GrLivArea')

# %%
plt.clf()
df.plot.scatter('GarageCars', 'SalePrice')
plt.show()

# %%
factors.append('GarageCars')

# %%
plt.clf()
df.plot.scatter('TotalBsmtSF', 'SalePrice')
plt.show()

# %%
factors.append('TotalBsmtSF')

# %% [markdown]
# First trial of regression

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
df[factors].describe()
# Out:
#        OverallQual    YearBuilt   MasVnrArea    GrLivArea   GarageCars  \
# count  1460.000000  1460.000000  1452.000000  1460.000000  1460.000000
# mean      6.099315  1971.267808   103.685262  1515.463699     1.767123
# std       1.382997    30.202904   181.066207   525.480383     0.747315
# min       1.000000  1872.000000     0.000000   334.000000     0.000000
# 25%       5.000000  1954.000000     0.000000  1129.500000     1.000000
# 50%       6.000000  1973.000000     0.000000  1464.000000     2.000000
# 75%       7.000000  2000.000000   166.000000  1776.750000     2.000000
# max      10.000000  2010.000000  1600.000000  5642.000000     4.000000
#
#        TotalBsmtSF
# count  1460.000000
# mean   1057.429452
# std     438.705324
# min       0.000000
# 25%     795.750000
# 50%     991.500000
# 75%    1298.250000
# max    6110.000000

# %%
df['MasVnrArea'] = df['MasVnrArea'].fillna(df['MasVnrArea'].mean())

# %%
from sklearn.cross_validation import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df[factors], Y, test_size=0.2, random_state=42)

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
from sklearn.metrics import mean_squared_error
print mean_squared_error(y_test, model.predict(X_test)) ** 0.5
# Out:
# 0.174438862881

# %%
df['SalePrice'].describe()
# Out:
# count    1460.000000
# mean       12.024051
# std         0.399452
# min        10.460242
# 25%        11.775097
# 50%        12.001505
# 75%        12.273731
# max        13.534473
# Name: SalePrice, dtype: float64

# %%
from sklearn.ensemble import GradientBoostingRegressor
model = GradientBoostingRegressor(random_state=1, n_estimators=50, max_depth=4)

# %%
model.fit(X_train, y_train)
# Out:
# GradientBoostingRegressor(alpha=0.9, init=None, learning_rate=0.1, loss='ls',
#              max_depth=4, max_features=None, max_leaf_nodes=None,
#              min_samples_leaf=1, min_samples_split=2,
#              min_weight_fraction_leaf=0.0, n_estimators=50, presort='auto',
#              random_state=1, subsample=1.0, verbose=0, warm_start=False)

# %%
print mean_squared_error(y_test, model.predict(X_test)) ** 0.5
# Out:
# 0.166598581278
